# %% [markdown]
# <a href="https://colab.research.google.com/github/harakunivj/demoproject/blob/master/GenAI_Usecases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install --upgrade --quiet google-cloud-aiplatform
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 53.5 MB/s eta 0:00:00

# %%
from inspect import cleandoc
from IPython.display import display, Markdown

import vertexai
from vertexai.generative_models import GenerativeModel, GenerationConfig

# %%
PROJECT = !gcloud config get-value project
PROJECT_ID = PROJECT[0]
REGION = "us-central1"
vertexai.init(project=PROJECT_ID, location=REGION)

# %%
model = GenerativeModel("gemini-2.0-flash-001")
# Out:
# /usr/local/lib/python3.11/dist-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()

# %%
creative_gen_config = GenerationConfig(temperature=1, top_p=0.8)

# %%
prompt = "What are some strategies for overcoming writer's block?"

response = model.generate_content(prompt,
                                  generation_config=creative_gen_config)
print(response.text)
# Out:
# Writer's block is a common and frustrating experience, but it's usually temporary and can be overcome. Here are some strategies to help you break through it:
#
# **1. Change Your Environment & Perspective:**
#
# *   **Change Location:** Move to a different room, a coffee shop, a park, or even just a different chair. A new environment can spark new ideas.
# *   **Change Time of Day:** If you usually write in the morning, try writing in the evening, or vice versa.
# *   **Take a Break (Actually):** Step away from your writing completely. Go for a walk, listen to music, meditate, do some exercise, or engage in a completely unrelated activity.  Sometimes, distance is the key.
# *   **Talk to Someone:** Discuss your project with a friend, family member, or colleague. Explaining your ideas out loud can help you clarify your thoughts and identify roadblocks.
# *   **Read Something Different:** Read something outside your usual genre or topic. This can expose you to new styles, ideas, and perspectives.
#
# **2. Freewriting & Brainstorming:**
#
# *   **Freewrite:** Set a timer for 5-10 minutes and write continuously, without worrying about grammar, spelling, or coherence. Just let your thoughts flow onto the page. This can help you uncover hidden ideas and break through mental barriers.
# *   **Brainstorm:** Generate a list of ideas related to your topic. Don't censor yourself – just write down everything that comes to mind, no matter how silly or irrelevant it seems.
# *   **Mind Mapping:** Create a visual representation of your ideas and their connections. Start with your central topic and branch out with related concepts, keywords, and images.
# *   **Questioning:** Ask yourself a series of questions about your topic. What are the key issues? Who are the main characters? What are the possible outcomes?
#
# **3. Focusing on the Process, Not the Product:**
#
# *   **Lower Your Expectations:** Stop aiming for perfection. Remind yourself that you're just trying to get something down on paper, and you can always edit it later.
# *   **Write Badly:** Intentionally write something terrible. This can take the pressure off and free you to experiment. You might be surprised at what you come up with.
# *   **Focus on a Small Task:** Instead of trying to tackle the entire project, break it down into smaller, more manageable tasks. Focus on writing just one paragraph, one scene, or one section.
# *   **Start in the Middle:** If you're stuck on the beginning, try writing a scene or section that you're excited about. You can always go back and write the introduction later.
# *   **Change Your Perspective (Character-Based):** If writing fiction, try writing from a different character's point of view.  How would *they* see the situation?
#
# **4. Structure & Outlining:**
#
# *   **Outline:** Create a detailed outline of your project. This can help you organize your thoughts and identify any gaps in your knowledge.
# *   **Reverse Outline:** If you've already written some of your project, create an outline of what you've written. This can help you identify areas that need improvement or expansion.
# *   **Use Templates or Prompts:** Find writing prompts or templates online that are related to your topic. These can provide a starting point and spark new ideas.
# *   **Storyboard:** For visual projects, create a storyboard to plan out the sequence of events.
#
# **5. Address the Underlying Issues:**
#
# *   **Identify the Cause:** Try to figure out *why* you're experiencing writer's block. Are you feeling overwhelmed, uninspired, or anxious?
# *   **Manage Stress and Anxiety:** If stress or anxiety is contributing to your writer's block, try relaxation techniques such as deep breathing, meditation, or yoga.
# *   **Prioritize Sleep and Self-Care:** Make sure you're getting enough sleep, eating healthy, and taking care of your physical and mental health.
# *   **Seek Professional Help:** If your writer's block is persistent and debilitating, consider seeking help from a therapist or writing coach.
#
# **6. Specific Techniques for Different Writing Types:**
#
# *   **Fiction:**
#     *   **Character Development:** Spend time developing your characters, their backstories, and their motivations.
#     *   **Worldbuilding:** Create a detailed world for your story to take place in.
#     *   **What If?** Ask yourself "What if...?" questions to explore different possibilities for your plot.
# *   **Non-Fiction:**
#     *   **Research:** Conduct thorough research on your topic.
#     *   **Organize Your Research:** Use note-taking software or a spreadsheet to organize your research findings.
#     *   **Identify Your Audience:** Who are you writing for? What do they already know about your topic?
# *   **Academic Writing:**
#     *   **Review the Literature:** Read and summarize relevant articles and books.
#     *   **Formulate a Thesis Statement:** Clearly state your main argument or point.
#     *   **Create an Argument:** Develop a logical and persuasive argument to support your thesis.
#
# **Key Takeaways:**
#
# *   **Be Patient:** Writer's block is a normal part of the writing process. Don't get discouraged.
# *   **Experiment:** Try different strategies until you find what works for you.
# *   **Be Kind to Yourself:** Don't beat yourself up for not being able to write.
# *   **Keep Writing:** Even if you're not writing well, keep writing. The more you write, the easier it will become.
#
# Ultimately, the best strategy for overcoming writer's block is to find what works for you and to keep practicing. Good luck!

# %%
prompt = "Provide ten interview questions for the role of prompt engineer."

response = model.generate_content(prompt,
                                  generation_config=creative_gen_config)
print(response.text)
# Out:
# Okay, here are ten interview questions for a prompt engineer role, covering a range of skills and knowledge areas:
#
# **Technical & Conceptual:**
#
# 1.  **Describe your experience with different types of large language models (LLMs) like GPT-3, LaMDA, or others. What are the strengths and weaknesses you've observed in each, and how does that influence your prompt engineering approach?** (This assesses familiarity with different models and their nuances.)
#
# 2.  **Explain the concept of "prompt engineering." What are the key principles and techniques you use to craft effective prompts for LLMs? Can you provide specific examples of techniques like few-shot learning, chain-of-thought prompting, or prompt chaining, and when you might use them?** (This tests the candidate's understanding of the core concepts and techniques.)
#
# 3.  **How do you approach a new task where you need to use an LLM, but you don't have any pre-existing prompts? Walk me through your process of exploration, experimentation, and refinement to achieve the desired outcome.** (This assesses problem-solving skills and the ability to iterate.)
#
# **Practical & Problem-Solving:**
#
# 4.  **Let's say you're tasked with using an LLM to generate creative content, like writing poems or short stories. However, the output is often generic and lacks originality. How would you modify your prompts to encourage more creative and unique responses?** (This assesses creativity and the ability to guide the LLM towards specific goals.)
#
# 5.  **You're working on a project where the LLM is generating factually incorrect information, also known as "hallucinations." What strategies would you employ to mitigate this issue and ensure the accuracy of the LLM's output?** (This tests knowledge of common LLM limitations and mitigation techniques.)
#
# **Analytical & Evaluation:**
#
# 6.  **How do you evaluate the quality and effectiveness of a prompt? What metrics or criteria do you use to determine if a prompt is "good" or needs improvement?  How do you measure success?** (This assesses analytical skills and the ability to define and measure prompt performance.)
#
# 7.  **Describe a situation where you had to debug a prompt that was not producing the expected results. What steps did you take to identify the problem and improve the prompt?** (This assesses troubleshooting skills and the ability to analyze prompt behavior.)
#
# **Communication & Collaboration:**
#
# 8.  **Imagine you need to explain the importance of prompt engineering to someone who is not familiar with LLMs. How would you communicate the value of your role and the impact it has on the overall project?** (This assesses communication skills and the ability to explain technical concepts to non-technical audiences.)
#
# 9.  **How do you stay up-to-date with the latest advancements in LLMs and prompt engineering techniques? What resources do you rely on for learning and inspiration?** (This assesses a commitment to continuous learning and staying current in a rapidly evolving field.)
#
# **Ethical & Responsible AI:**
#
# 10. **LLMs can sometimes generate biased or harmful content. How do you approach the ethical considerations of prompt engineering, and what steps do you take to prevent the generation of biased or offensive output?** (This assesses awareness of ethical considerations and the ability to promote responsible AI development.)
#
# These questions cover a wide range of topics relevant to a prompt engineer role and should help you assess the candidate's skills, knowledge, and experience. Remember to tailor the questions to the specific requirements of your project and organization. Good luck!

# %%
predictable_gen_config = GenerationConfig(temperature=0.1, top_p=0.1)

# %%
prompt = """
Given a user's input, classify their intent, such as "finding information", "making a reservation", or "placing an order". \n
user input: Hi, can you please book a table for two at Juan for May 1?
"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# Making a reservation.

# %%
prompt = """
What is the topic for a given news headline? \n
- business \n
- entertainment \n
- health \n
- sports \n
- technology \n\n

Text: Pixel 7 Pro Expert Hands On Review. \n
The answer is: technology \n

Text: Quit smoking? \n
The answer is: health \n

Text: Birdies or bogeys? Top 5 tips to hit under par \n
The answer is: sports \n

Text: Relief from local minimum-wage hike looking more remote \n
The answer is: business \n

Text: You won't guess who just arrived in Bari, Italy for the movie premiere. \n
The answer is:
"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# entertainment

# %%
import pandas as pd
from sklearn.metrics import classification_report

review_data_df = pd.DataFrame(
    {
        "review": [
            "i love this product. it does have everything i am looking for!",
            "all i can say is that you will be happy after buying this product",
            "its way too expensive and not worth the price",
            "i am feeling okay. its neither good nor too bad.",
        ],
        "sentiment_groundtruth": ["positive", "positive", "negative", "neutral"],
    }
)

review_data_df
# Out:
#                                               review sentiment_groundtruth
# 0  i love this product. it does have everything i...              positive
# 1  all i can say is that you will be happy after ...              positive
# 2      its way too expensive and not worth the price              negative
# 3   i am feeling okay. its neither good nor too bad.               neutral

# %%
review_data_df
# Out:
#                                               review sentiment_groundtruth
# 0  i love this product. it does have everything i...              positive
# 1  all i can say is that you will be happy after ...              positive
# 2      its way too expensive and not worth the price              negative
# 3   i am feeling okay. its neither good nor too bad.               neutral

# %%
def get_sentiment(row):
    prompt = f"""Classify the sentiment of the following review as "positive", "neutral" or "negative". Return only the classification.
                review: {row}
              """
    response = model.generate_content(
        contents=prompt, generation_config=predictable_gen_config
    ).text
    return response


review_data_df["sentiment_prediction"] = review_data_df["review"].apply(get_sentiment)
review_data_df
# Out:
#                                               review sentiment_groundtruth  \
# 0  i love this product. it does have everything i...              positive
# 1  all i can say is that you will be happy after ...              positive
# 2      its way too expensive and not worth the price              negative
# 3   i am feeling okay. its neither good nor too bad.               neutral
#
#   sentiment_prediction
# 0           positive\n
# 1           positive\n
# 2           Negative\n
# 3            Neutral\n

# %%
report = classification_report(
    review_data_df["sentiment_groundtruth"], review_data_df["sentiment_prediction"]
)
Markdown(report)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#    Negative
#        0.00      0.00      0.00       0.0
#     Neutral
#        0.00      0.00      0.00       0.0
#     negative       0.00      0.00      0.00       1.0
#      neutral       0.00      0.00      0.00       1.0
#     positive       0.00      0.00      0.00       2.0
#    positive
#        0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       4.0
#    macro avg       0.00      0.00      0.00       4.0
# weighted avg       0.00      0.00      0.00       4.0

# %%
predictable_gen_config = GenerationConfig(temperature=0.1, top_p=0.1)

# %%
prompt = """
Provide a very short summary, no more than three sentences, for the following article:

Our quantum computers work by manipulating qubits in an orchestrated fashion that we call quantum algorithms.
The challenge is that qubits are so sensitive that even stray light can cause calculation errors — and the problem worsens as quantum computers grow.
This has significant consequences, since the best quantum algorithms that we know for running useful applications require the error rates of our qubits to be far lower than we have today.
To bridge this gap, we will need quantum error correction.
Quantum error correction protects information by encoding it across multiple physical qubits to form a "logical qubit," and is believed to be the only way to produce a large-scale quantum computer with error rates low enough for useful calculations.
Instead of computing on the individual qubits themselves, we will then compute on logical qubits. By encoding larger numbers of physical qubits on our quantum processor into one logical qubit, we hope to reduce the error rates to enable useful quantum algorithms.

Summary:

"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# Quantum computers are prone to errors due to qubit sensitivity, hindering the execution of complex algorithms. Quantum error correction, which encodes information across multiple physical qubits to form a more stable "logical qubit," is necessary to reduce error rates. This approach is crucial for building large-scale, reliable quantum computers capable of performing useful calculations.

# %%
prompt = """
Provide a very short summary in four bullet points for the following article:

Our quantum computers work by manipulating qubits in an orchestrated fashion that we call quantum algorithms.
The challenge is that qubits are so sensitive that even stray light can cause calculation errors — and the problem worsens as quantum computers grow.
This has significant consequences, since the best quantum algorithms that we know for running useful applications require the error rates of our qubits to be far lower than we have today.
To bridge this gap, we will need quantum error correction.
Quantum error correction protects information by encoding it across multiple physical qubits to form a "logical qubit," and is believed to be the only way to produce a large-scale quantum computer with error rates low enough for useful calculations.
Instead of computing on the individual qubits themselves, we will then compute on logical qubits. By encoding larger numbers of physical qubits on our quantum processor into one logical qubit, we hope to reduce the error rates to enable useful quantum algorithms.

Bullet points:

"""

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
Markdown(response.text)
# Out:
# Here's a four-bullet-point summary:
#
# *   Quantum computers use qubits, which are highly susceptible to errors.
# *   Current error rates are too high for running useful quantum algorithms.
# *   Quantum error correction, using "logical qubits," is needed to reduce errors.
# *   Logical qubits encode information across multiple physical qubits for improved accuracy.

# %%
prompt = """
Please generate a summary of the following conversation and at the end summarize the to-do's for the support Agent:

Customer: Hi, I'm Larry, and I received the wrong item.

Support Agent: Hi, Larry. How would you like to see this resolved?

Customer: That's alright. I want to return the item and get a refund, please.

Support Agent: Of course. I can process the refund for you now. Can I have your order number, please?

Customer: It's [ORDER NUMBER].

Support Agent: Thank you. I've processed the refund, and you will receive your money back within 14 days.

Customer: Thank you very much.

Support Agent: You're welcome, Larry. Have a good day!

Summary:
"""

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
Markdown(response.text)
# Out:
# Larry contacted support because he received the wrong item. He requested a refund for the incorrect item and to return it. The support agent processed the refund after obtaining the order number. Larry was informed that he would receive the refund within 14 days.
#
# To-Do's for the Support Agent:
#
# *   **Process the refund:** This has already been completed.
# *   **Ensure the refund is properly documented in the system.**
# *   **Potentially provide instructions or a return label for Larry to return the incorrect item (this was not explicitly mentioned in the conversation but is a standard practice).**
# *   **Follow up with Larry in 14 days if he has not received the refund.**

# %%
order = "We need eight grilled cheese sandwiches. Two with swiss cheese, three with muenster, three with cheddar."

prompt = """
    Break the customer's order into individual items with keys for the following fields:
    - item_name
    - cheese_selection

    Order:
    {order_field}
""".format(order_field=order)

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# ```json
# [
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Swiss"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Swiss"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   }
# ]
# ```

# %%
prompt = """Q: Who was President of the United States in 1955?
              Which party did he belong to?
            A:
        """
response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# A: Dwight D. Eisenhower
#    Republican Party

# %%
context = """
Storage and content policy \n
How durable is my data in Cloud Storage? \n
Cloud Storage is designed for 99.999999999% (11 9's) annual durability, which is appropriate for even primary storage and
business-critical applications. This high durability level is achieved through erasure coding that stores data pieces redundantly
across multiple devices located in multiple availability zones.
Objects written to Cloud Storage must be redundantly stored in at least two different availability zones before the
write is acknowledged as successful. Checksums are stored and regularly revalidated to proactively verify that the data
integrity of all data at rest as well as to detect corruption of data in transit. If required, corrections are automatically
made using redundant data. Customers can optionally enable object versioning to add protection against accidental deletion.
"""

question = "How is high availability achieved?"

prompt = f"""Answer the question given in the contex below:
Context: {context}?\n
Question: {question} \n
Answer:
"""

print("[Prompt]")
print(prompt)

print("[Response]")
response = model.generate_content(contents=prompt, generation_config=predictable_gen_config)
print(response.text)
# Out:
# [Prompt]
# Answer the question given in the contex below:
# Context:
# Storage and content policy
#
# How durable is my data in Cloud Storage?
#
# Cloud Storage is designed for 99.999999999% (11 9's) annual durability, which is appropriate for even primary storage and
# business-critical applications. This high durability level is achieved through erasure coding that stores data pieces redundantly
# across multiple devices located in multiple availability zones.
# Objects written to Cloud Storage must be redundantly stored in at least two different availability zones before the
# write is acknowledged as successful. Checksums are stored and regularly revalidated to proactively verify that the data
# integrity of all data at rest as well as to detect corruption of data in transit. If required, corrections are automatically
# made using redundant data. Customers can optionally enable object versioning to add protection against accidental deletion.
# ?
#
# Question: How is high availability achieved?
#
# Answer:
#
# [Response]
# High availability is achieved through erasure coding that stores data pieces redundantly across multiple devices located in multiple availability zones. Objects are redundantly stored in at least two different availability zones before the write is acknowledged as successful.
